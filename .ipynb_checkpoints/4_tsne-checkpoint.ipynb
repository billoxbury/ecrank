# %% [markdown]
# ## t-SNE to the plane

# %%
import pandas as pd

dffile = "./data/ec_rk0-2_cond1000-10000.csv"

df = pd.read_csv(dffile)
df
# Out:
#             ec  rank  conductor  a1  a2  a3  a4  a5  a6  a7  ...  a991  a992  \
# 0      1001.b1     0       1001  -1   0  -2  -1   1  -1  -2  ...   -30   -78
# 1      1001.b2     0       1001  -1   0  -2  -1   1  -1  -2  ...   -30   -78
# 2      1001.b3     0       1001  -1   0  -2  -1   1  -1  -2  ...   -30   -78
# 3      1001.b4     0       1001  -1   0  -2  -1   1  -1  -2  ...   -30   -78
# 4      1002.a1     0       1002  -1  -1   0   0   0  -4   6  ...    50   154
# ...        ...   ...        ...  ..  ..  ..  ..  ..  ..  ..  ...   ...   ...
# 59568  9962.a1     2       9962   1  -1  -4   1  -4  -6  -1  ...  -144    99
# 59569  9963.c1     2       9963   0   0  -2  -4   2  -1  -2  ...    94   -14
# 59570  9966.c1     2       9966   1  -1  -3  -4  -1  -3  -4  ...    96   108
# 59571  9978.a1     2       9978  -1  -1  -2  -1  -1  -2  -5  ...  -117    31
# 59572  9999.e1     2       9999   0   0  -3   0  -1  -5   3  ...   142   -54
#
#        a993  a994  a995  a996  a997  a998  a999  a1000
# 0       100   -18   -90   136  -132  -106  -100    -48
# 1       100   -18   -90   136  -132  -106  -100    -48
# 2       100   -18   -90   136  -132  -106  -100    -48
# 3       100   -18   -90   136  -132  -106  -100    -48
# 4       152   -34    74   128   102   -96   116     -4
# ...     ...   ...   ...   ...   ...   ...   ...    ...
# 59568    77   146   -36   108    72  -122   126    -49
# 59569   139  -127    36   -64   -88    42   114    -12
# 59570    32    66   -46   -21   -67   110    94     86
# 59571   174   101  -126    47  -111    21    54    -86
# 59572    -8  -138   146    16    91    73   168    108
#
# [59573 rows x 1003 columns]

# %% [markdown]
# Quick check on the correctness of random data frame entries:

# %%
i = randint(0,df.shape[0]-1)
j = randint(1,1000)

E = EllipticCurve(QQ, df['ec'].values[i])
p = Primes().unrank(j-1)
a = 'a' + str(j)

print(E)
print(f'Prime {p}')
print(f'Check p+1-|Ep| = {df[a].values[i]} ... {p+1-E.Np(p) == df[a].values[i]}')
print(f'Check conductor = {df["conductor"].values[i]} ... {E.conductor() == df["conductor"].values[i]}')
print(f'Check rank = {df["rank"].values[i]} ... {E.rank() == df["rank"].values[i]}')
# Out:
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 - 959*x - 11835 over Rational Field
# Prime 2719
# Check p+1-|Ep| = 52 ... True
# Check conductor = 4902 ... True
# Check rank = 1 ... True

# %% [markdown]
# Extract array and compute t-SNE dimensional reduction:

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

# sample rows uniformly
#ssize = 10000
#idx = sorted([choice(range(0,df.shape[0])) for _ in range(ssize)])

# or by size of conductor
idx = [i for i in range(df.shape[0]) if df["conductor"][i] > 8000]

# extract features to use
nprimes = 50
idy = ['a'+str(i) for i in range(1,nprimes + 1)]

# high-dimensional array
X = df[idy].iloc[idx].to_numpy()

# t-SNE computation
X_tsne = TSNE(n_components = 2).fit_transform(X)
print(f'tSNE frame {X_tsne.shape}')

# PCA decomposition for comparison
X_pca = PCA().fit_transform(X)
print(f'PCA frame {X_pca.shape}')
# Out:
# tSNE frame (13332, 2)
# PCA frame (13332, 50)

# %% [markdown]
# Create new data frame (and write to file if necessary):

# %%
df_proj = df.iloc[idx][['ec','rank','conductor']]

df_proj['x1'] = X_tsne[:,0]
df_proj['x2'] = X_tsne[:,1]
df_proj['z1'] = X_pca[:,0]
df_proj['z2'] = X_pca[:,1]

df_proj
# Out:
#             ec  rank  conductor         x1         x2         z1         z2
# 21319  8001.g1     0       8001  -4.881057  23.511044 -10.347129  26.731359
# 21320  8004.b1     0       8004  52.991276  18.223883  -4.010063   3.165006
# 21321  8008.a1     0       8008  53.524780  40.033707   3.717208   8.889004
# 21322  8008.d1     0       8008  47.926708 -15.510921  34.905781  14.418343
# 21323  8008.d2     0       8008  47.926708 -15.510921  34.905781  14.418343
# ...        ...   ...        ...        ...        ...        ...        ...
# 59568  9962.a1     2       9962 -57.186302  26.957439  -0.516179  -0.690176
# 59569  9963.c1     2       9963 -87.234421  46.908722 -16.694749  -3.869330
# 59570  9966.c1     2       9966  58.023922 -42.206940  17.606662  12.193398
# 59571  9978.a1     2       9978 -50.279778 -49.989655  -5.758134  -7.314361
# 59572  9999.e1     2       9999 -68.916878   7.232259 -24.532019 -13.143438
#
# [13332 rows x 7 columns]

# %% [markdown]
# Plot points in the plane:

# %%
from matplotlib import pyplot as plt

c = df_proj['rank']

plt.figure(figsize=(10,10))
plt.scatter(df_proj['x1'],
            df_proj['x2'], 
            s=0.5, c=c)
plt.title("t-SNE")
plt.show()

plt.figure(figsize=(10,10))
plt.scatter(df_proj['z1'],
            df_proj['z2'], 
            s=0.5, c=c)
plt.title("PCA")
plt.show()

# %% [markdown]
# ## Taking initial window averages as feature vector

# %% [markdown]
# Motivated by the analysis in the notebook _primeseries_, we can see a better feature set to try: namely the vector of initial moving averages over succesively larger window sizes.

# %%
import numpy as np

nprimes = 100
rg = range(1,nprimes+1)
v = ['a'+str(j) for j in range(1,nprimes+1)]

for j in range(1,nprimes+1):
    df['b'+str(j)] = df[v[:j]].mean(axis=1)
    
df
# Out:
#             ec  rank  conductor  a1  a2  a3  a4  a5  a6  a7  ...       b91  \
# 0      1001.b1     0       1001  -1   0  -2  -1   1  -1  -2  ...  2.373626
# 1      1001.b2     0       1001  -1   0  -2  -1   1  -1  -2  ...  2.373626
# 2      1001.b3     0       1001  -1   0  -2  -1   1  -1  -2  ...  2.373626
# 3      1001.b4     0       1001  -1   0  -2  -1   1  -1  -2  ...  2.373626
# 4      1002.a1     0       1002  -1  -1   0   0   0  -4   6  ...  1.307692
# ...        ...   ...        ...  ..  ..  ..  ..  ..  ..  ..  ...       ...
# 59568  9962.a1     2       9962   1  -1  -4   1  -4  -6  -1  ... -1.857143
# 59569  9963.c1     2       9963   0   0  -2  -4   2  -1  -2  ...  0.637363
# 59570  9966.c1     2       9966   1  -1  -3  -4  -1  -3  -4  ... -1.186813
# 59571  9978.a1     2       9978  -1  -1  -2  -1  -1  -2  -5  ... -1.065934
# 59572  9999.e1     2       9999   0   0  -3   0  -1  -5   3  ... -1.318681
#
#             b92       b93       b94       b95       b96       b97       b98  \
# 0      2.608696  2.924731  3.191489  3.115789  3.083333  3.360825  3.020408
# 1      2.608696  2.924731  3.191489  3.115789  3.083333  3.360825  3.020408
# 2      2.608696  2.924731  3.191489  3.115789  3.083333  3.360825  3.020408
# 3      2.608696  2.924731  3.191489  3.115789  3.083333  3.360825  3.020408
# 4      1.554348  1.365591  1.436170  1.231579  0.968750  1.061856  0.948980
# ...         ...       ...       ...       ...       ...       ...       ...
# 59568 -1.445652 -1.591398 -1.744681 -1.747368 -1.708333 -1.742268 -2.000000
# 59569  0.413043  0.677419  0.776596  0.305263  0.177083  0.587629  0.397959
# 59570 -1.391304 -0.967742 -0.968085 -0.905263 -0.697917 -1.061856 -1.275510
# 59571 -0.826087 -0.903226 -1.106383 -0.715789 -0.583333 -0.670103 -1.071429
# 59572 -1.717391 -1.655914 -1.478723 -1.305263 -0.895833 -0.453608 -0.193878
#
#             b99  b100
# 0      2.787879  3.14
# 1      2.787879  3.14
# 2      2.787879  3.14
# 3      2.787879  3.14
# 4      0.696970  0.37
# ...         ...   ...
# 59568 -2.414141 -2.73
# 59569  0.484848  0.38
# 59570 -1.404040 -1.43
# 59571 -0.858586 -1.05
# 59572 -0.434343 -0.74
#
# [59573 rows x 1103 columns]

# %% [markdown]
# Select rows/features and compute dimensional reductions:

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

# sample rows uniformly
ssize = 10000
idx = sorted([choice(range(0,df.shape[0])) for _ in range(ssize)])

# or by size of conductor
#idx = [i for i in range(df.shape[0]) if df["conductor"][i] > 8000]

# extract features to use
idy = ['b'+str(i) for i in range(1,nprimes + 1)]

# high-dimensional array
X = df[idy].iloc[idx].to_numpy()

# t-SNE computation
X_tsne = TSNE(n_components = 2).fit_transform(X)
print(f'tSNE frame {X_tsne.shape}')

# PCA decomposition for comparison
X_pca = PCA().fit_transform(X)
print(f'PCA frame {X_pca.shape}')

# make data frame
df_proj = df.iloc[idx][['ec','rank','conductor']]

df_proj['x1'] = X_tsne[:,0]
df_proj['x2'] = X_tsne[:,1]
df_proj['z1'] = X_pca[:,0]
df_proj['z2'] = X_pca[:,1]

df_proj

# %% [markdown]
# Check the rank distribution on this subframe:

# %%
from collections import Counter

Counter(df_proj["rank"])
# Out:
# Counter({1: 15035, 0: 13819, 2: 1146})

# %% [markdown]
# Plot the results:

# %%
from matplotlib import pyplot as plt
from matplotlib import rc

rc('figure', figsize=(10, 10))

c = df_proj['rank']
col = ['blue', 'orange', 'green']

# PCA
fig, ax = plt.subplots()
for i in range(3):
    x = df_proj['z1'][c==i], 
    y = df_proj['z2'][c==i], 
    ax.scatter(x, y,
               s = 0.5,
               c=col[i], 
               label='Rank '+str(i))
ax.legend()
ax.grid(False)
plt.title('PCA')
plt.show()

# t-SNE
fig, ax = plt.subplots()
for i in range(3):
    x = df_proj['x1'][c==i], 
    y = df_proj['x2'][c==i], 
    ax.scatter(x, y,
               s = 0.5,
               c=col[i], 
               label='Rank '+str(i))
ax.legend()
ax.grid(False)
plt.title('t-SNE')
plt.show()

# %% [markdown]
# Save the results:

# %%
dffile = "./data/ec_rk0-2_cond1000-10000_proj.csv"
df_proj.to_csv(dffile, index=False)
